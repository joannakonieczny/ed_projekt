# %%
include("parse.jl")
include("plots.jl")
# Out:
# abstract_vs_main_category_sort (generic function with 1 method)

# %%
df = load_data("arxiv-metadata-oai-snapshot.json")
first(df, 5)
# Out:
# 5×5 DataFrame
#  Row │ date        id         abstract  categories              authors        ⋯
#      │ Date        String     Int64     Array…                  Array…         ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ 2008-11-26  0704.0001       983  ["hep-ph"]              ["Balázs C.",  ⋯
#    2 │ 2008-12-13  0704.0002       798  ["math.CO", "cs.CG"]    ["Streinu Ilea
#    3 │ 2008-01-13  0704.0003       880  ["physics.gen-ph"]      ["Pan Hongjun"
#    4 │ 2007-05-23  0704.0004       248  ["math.CO"]             ["Callan David
#    5 │ 2013-10-15  0704.0005       223  ["math.CA", "math.FA"]  ["Abu-Shammala ⋯
#                                                                 1 column omitted

# %%
articles_per_year(df)

# %%
abstract_lengths_norm(df)

# %%
author_amounts_norm(df)

# %%
abstract_vs_category(df)

# %%
article_types_sort(df)

# %%
abstract_vs_category_sort(df)
